# %% [markdown]
# # Multi Variable Regression

# %%
import tensorflow as tf
# Data
x1_data = [73.,93.,89.,96.,73.]
x2_data = [80.,88.,91.,98.,66.]
x3_data = [75.,93.,90.,100.,70.]
y_data = [152.,185.,180.,196.,142.]
# Placeholder
x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
# Vaiables
w1 = tf.Variable(tf.random_normal([1]), name='weight1')
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')
# Hypothesis
hypothesis = x1*w1 + x2*w2 + x3*w3 + b

# %%
# Cost/Loss Function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# Minimize : Gradient Descent 
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Session start
sess = tf.Session()
# initialize variables
sess.run(tf.global_variables_initializer())
# run
for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict = {x1:x1_data, x2:x2_data, x3:x3_data, Y:y_data})
    
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val )
# Out:
# 0 Cost:  67834.33
# Prediction:
#  [ -77.70052   -94.32473   -92.29841  -102.320625  -70.709564]
# 10 Cost:  2.0375392
# Prediction:
#  [152.69154 182.59705 180.55331 194.80875 140.51338]
# 20 Cost:  1.4107492
# Prediction:
#  [153.38452 183.4377  181.3776  195.70702 141.15593]
# 30 Cost:  1.40496
# Prediction:
#  [153.38255 183.44301 181.37881 195.70905 141.16135]
# 40 Cost:  1.39921
# Prediction:
#  [153.37848 183.44579 181.37755 195.70831 141.16481]
# 50 Cost:  1.393481
# Prediction:
#  [153.37442 183.44855 181.37627 195.70761 141.16827]
# 60 Cost:  1.387791
# Prediction:
#  [153.37038 183.45131 181.375   195.7069  141.17172]
# 70 Cost:  1.3821242
# Prediction:
#  [153.36632 183.45406 181.37373 195.70616 141.17516]
# 80 Cost:  1.3765066
# Prediction:
#  [153.3623  183.45679 181.37247 195.70547 141.17857]
# 90 Cost:  1.3709157
# Prediction:
#  [153.35829 183.45952 181.37122 195.70476 141.18199]
# 100 Cost:  1.3653346
# Prediction:
# ...

# %% [markdown]
# ### 이러한 방법은 쓰지 않는다. => Martix 를 이용한 방법

# %%
# Matrix Form
x_data = [[73.,80.,75.], [93.,88.,93.], [89.,91.,90.], [96.,98.,100.], [73.,66.,70.]]
y_data = [[152.],[185.],[180.],[196.],[142.]]
# placeholder
X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

W = tf.Variable(tf.random_normal([3,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b

# %%
# Cost/Loss Function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# Minimize : Gradient Descent 
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Session start
sess = tf.Session()
# initialize variables
sess.run(tf.global_variables_initializer())
# run
for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict = {X:x_data, Y:y_data})
    
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val )
# Out:
# 0 Cost:  7855.6274
# Prediction:
#  [[66.9619  ]
#  [85.09745 ]
#  [81.25945 ]
#  [91.837814]
#  [63.149765]
#  [51.97072 ]
#  [72.20036 ]
#  [58.28623 ]
#  [84.53534 ]
#  [85.90582 ]
#  [67.502686]
#  [69.785774]
#  [80.68866 ]
#  [62.567444]
#  [73.5679  ]
#  [89.07847 ]
#  [56.959995]
#  [87.81536 ]
#  [75.682   ]
#  [67.758644]
#  [84.25635 ]
#  [82.71003 ]
#  [78.985054]
#  [59.86811 ]
#  [85.96572 ]]
# 10 Cost:  19.671186
# Prediction:
#  [[149.63312]
#  [184.44064]
#  [179.15489]
#  [198.44516]
#  [138.91692]
#  [107.81575]
#  [151.9931 ]
#  [117.43109]
#  [177.36395]
#  [171.86777]
#  [144.38135]
#  [145.57777]
#  [181.83624]
#  [146.6611 ]
#  [153.72353]
#  [189.88248]
#  [137.0519 ]
#  [183.57391]
#  [172.11613]
#  [154.04489]
#  [177.82605]
#  [175.90053]
#  [168.20044]
#  [143.23926]
#  [188.93045]]
# 20 Cost:  19.183142
# Prediction:
#  [[150.21762 ]
#  [185.12314 ]
#  [179.83836 ]
#  [199.18143 ]
#  [139.43912 ]
#  [108.18591 ]
#  [152.53784 ]
#  [117.826546]
# ...

# %% [markdown]
# # Data Load

# %%
import tensorflow as tf
import numpy as np

xy = np.loadtxt('/Users/Baobab/Desktop/DeepLearning/DeepLearningZeroToAll/data-01-test-score.csv', 
                delimiter = ',', dtype=np.float32)

# %%
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]
# Shape 와 data 확인
print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (25, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]] 25
# (25, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
# Placeholder
X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

W = tf.Variable(tf.random_normal([3,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')
# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Cost function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# Optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session
sess = tf.Session()
# variable 초기화
sess.run(tf.global_variables_initializer())
# run
for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict={X:x_data, Y:y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  158.4311
# Prediction:
#  [[136.38611]
#  [175.27924]
#  [166.55571]
#  [184.97906]
#  [133.54932]
#  [105.33797]
#  [140.62354]
#  [106.9304 ]
#  [170.8362 ]
#  [167.1913 ]
#  [135.18478]
#  [139.68642]
#  [168.59824]
#  [135.79144]
#  [143.36444]
#  [180.23868]
#  [128.49219]
#  [168.3887 ]
#  [158.4152 ]
#  [141.16954]
#  [165.25069]
#  [167.21492]
#  [155.5685 ]
#  [129.36862]
#  [178.18062]]
# 10 Cost:  36.360218
# Prediction:
#  [[146.71754]
#  [187.6535 ]
#  [178.7714 ]
#  [198.2722 ]
#  [142.98477]
#  [112.27283]
#  [150.57016]
#  [114.30024]
#  [182.37778]
#  [177.85419]
#  [144.76595]
#  [149.11049]
#  [181.22888]
#  [146.30357]
#  [153.34917]
#  [192.78946]
#  [138.50314]
#  [180.32889]
#  [170.46506]
#  [151.95403]
#  [176.91228]
#  [178.81601]
#  [166.6936 ]
#  [139.80905]
#  [191.01692]]
# 20 Cost:  36.090668
# Prediction:
#  [[146.8145 ]
#  [187.72704]
#  [178.86685]
#  [198.36557]
#  [143.03891]
#  [112.29135]
#  [150.63635]
#  [114.34538]
#  [182.42354]
# ...

# %%
# My score prediction
print("Your score will be ", sess.run(hypothesis, feed_dict={X:[[100,70,101]]}))
print("Other score will be ", sess.run(hypothesis, feed_dict={X:[[60,70,110],[90,100,80]]}))
# Out:
# Your score will be  [[198.39615]]
# Other score will be  [[191.78479]
#  [167.93242]]

# %% [markdown]
# # Queue Runners

# %%
import tensorflow as tf

filename_queue = tf.train.string_input_producer(['/Users/Baobab/Desktop/DeepLearning/DeepLearningZeroToAll/data-01-test-score.csv'],
                                               shuffle=False, name='filename_queue')
reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# %%
# Default values, decode result
record_defaults = [[0.], [0.], [0.], [0.]] # 이러한 형태로 읽는다.
xy = tf.decode_csv(value, record_defaults=record_defaults)

# collect batches
train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10) # 10개씩 batch한다.
    
# Placeholder
X = tf.placeholder(tf.float32, shape=[None,3])
Y = tf.placeholder(tf.float32, shape=[None,1])

W = tf.Variable(tf.random_normal([3,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X , W) + b

# Cost Function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize 
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the Graph
sess = tf.Session()
# Initialize variables
sess.run(tf.global_variables_initializer())

# Start populating the filename queue
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], feed_dict={X:x_batch, Y:y_batch})
    if step % 10 == 0: 
        print(step, "Cost: ", cost_val,
             "\nPrediction:\n", hy_val)
        
coord.request_stop()
coord.join(threads)
# Out:
# 0 Cost:  21387.217
# Prediction:
#  [[1.7234215]
#  [3.428837 ]
#  [4.43786  ]
#  [2.937422 ]
#  [6.412211 ]
#  [3.599807 ]
#  [5.1743608]
#  [4.165543 ]
#  [1.3909839]
#  [2.1003668]]
# 10 Cost:  6.3959556
# Prediction:
#  [[174.08487]
#  [163.18063]
#  [142.43484]
#  [142.07486]
#  [185.44986]
#  [153.26134]
#  [148.92784]
#  [187.70435]
#  [145.97937]
#  [177.06802]]
# 20 Cost:  5.815072
# Prediction:
#  [[175.28006]
#  [164.29091]
#  [143.42735]
#  [143.05202]
#  [186.75136]
#  [154.34056]
#  [149.96548]
#  [189.00313]
#  [147.00368]
#  [178.31041]]
# 30 Cost:  5.811967
# Prediction:
#  [[175.28621]
#  [164.29977]
#  [143.4354 ]
#  [143.05835]
#  [186.7579 ]
#  [154.34332]
#  [149.9766 ]
#  [189.01093]
#  [147.00278]
#  [178.32654]]
# 40 Cost:  5.8040123
# Prediction:
#  [[175.28426]
#  [164.3011 ]
#  [143.43669]
#  [143.05804]
#  [186.75563]
#  [154.33875]
#  [149.98067]
#  [189.00993]
#  [146.99489]
#  [178.33429]]
# 50 Cost:  5.796147
# Prediction:
#  [[175.28226]
# ...
